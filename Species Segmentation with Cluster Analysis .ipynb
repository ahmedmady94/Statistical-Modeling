# %% [markdown]
# # Species Segmentation with Cluster Analysis

# %% [markdown]
# ## Import the relevant libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

# %% [markdown]
# ## Load the data

# %% [markdown]
# Load data from the csv file: <i> 'iris_dataset.csv'</i>.

# %%
data= pd.read_csv('iris_dataset.csv')
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# ## Plot the data

# %%
plt.scatter(data['sepal_length'],data['sepal_width'])
plt.show()

# %% [markdown]
# # Clustering (unscaled data)

# %% [markdown]
# Separate the original data into 2 clusters.

# %%
x= data.copy()
x
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
kmeans= KMeans(2)
kmeans.fit(x)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
clusters= kmeans.fit_predict(x)
data_with_clusters= data.copy()
data_with_clusters['pred_clusters']= clusters
data_with_clusters
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  pred_clusters
# 0             5.1          3.5           1.4          0.2              1
# 1             4.9          3.0           1.4          0.2              1
# 2             4.7          3.2           1.3          0.2              1
# 3             4.6          3.1           1.5          0.2              1
# 4             5.0          3.6           1.4          0.2              1
# ..            ...          ...           ...          ...            ...
# 145           6.7          3.0           5.2          2.3              0
# 146           6.3          2.5           5.0          1.9              0
# 147           6.5          3.0           5.2          2.0              0
# 148           6.2          3.4           5.4          2.3              0
# 149           5.9          3.0           5.1          1.8              0
#
# [150 rows x 5 columns]

# %%
plt.scatter(data['sepal_length'],data['sepal_width'],c= data_with_clusters['pred_clusters'],cmap='rainbow')
plt.show()

# %% [markdown]
# # Standardize the variables

# %%
from sklearn import preprocessing
x_scaled= preprocessing.scale(x)
x_scaled
# Out:
# array([[-9.00681170e-01,  1.03205722e+00, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.14301691e+00, -1.24957601e-01, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.38535265e+00,  3.37848329e-01, -1.39813811e+00,
#         -1.31297673e+00],
#        [-1.50652052e+00,  1.06445364e-01, -1.28440670e+00,
#         -1.31297673e+00],
#        [-1.02184904e+00,  1.26346019e+00, -1.34127240e+00,
#         -1.31297673e+00],
#        [-5.37177559e-01,  1.95766909e+00, -1.17067529e+00,
#         -1.05003079e+00],
#        [-1.50652052e+00,  8.00654259e-01, -1.34127240e+00,
#         -1.18150376e+00],
#        [-1.02184904e+00,  8.00654259e-01, -1.28440670e+00,
#         -1.31297673e+00],
#        [-1.74885626e+00, -3.56360566e-01, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.14301691e+00,  1.06445364e-01, -1.28440670e+00,
#         -1.44444970e+00],
#        [-5.37177559e-01,  1.49486315e+00, -1.28440670e+00,
#         -1.31297673e+00],
# ...

# %% [markdown]
# # Clustering (scaled data)

# %%
kmeans= KMeans(3)
kmeans.fit(x_scaled)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
new_clusters= kmeans.fit_predict(x_scaled)
data_clustered = data.copy()
data_clustered['pred_clusters']= new_clusters

# %%
plt.scatter(data['sepal_length'],data['sepal_width'],c= data_clustered['pred_clusters'],cmap='rainbow')
plt.show()

# %% [markdown]
# ## Take Advantage of the Elbow Method

# %% [markdown]
# ### WCSS

# %%
def Elbow(x,n):
    
    wcss=[]
    for i in range(1,n):
        kmeans= KMeans(i)
        kmeans.fit(x)
        wcss_iter= kmeans.inertia_
        wcss.append(wcss_iter)
    number_clusters = [a for a in range(1,n)]
    plt.plot(number_clusters,wcss)
    plt.title('Elbow')
    plt.xlabel('number of clusters',fontsize='20')
    plt.ylabel('wcss',fontsize='20')
    plt.xlim(0,n)
    plt.show()

# %% [markdown]
# ### The Elbow Method

# %%
Elbow(x_scaled,10)

# %% [markdown]
# How many clusters are there?

# %%
y=data_with_clusters.copy()
y
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  pred_clusters
# 0             5.1          3.5           1.4          0.2              1
# 1             4.9          3.0           1.4          0.2              1
# 2             4.7          3.2           1.3          0.2              1
# 3             4.6          3.1           1.5          0.2              1
# 4             5.0          3.6           1.4          0.2              1
# ..            ...          ...           ...          ...            ...
# 145           6.7          3.0           5.2          2.3              0
# 146           6.3          2.5           5.0          1.9              0
# 147           6.5          3.0           5.2          2.0              0
# 148           6.2          3.4           5.4          2.3              0
# 149           5.9          3.0           5.1          1.8              0
#
# [150 rows x 5 columns]

# %%
y= y.drop(['pred_clusters'],axis=1)
y
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
sns.clustermap(y,cmap='mako')
